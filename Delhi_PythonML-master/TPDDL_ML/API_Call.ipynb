# %%
# API - Application Programming Interface
# JSON - Javascript Object Notation

# %%
import urllib.request as url
import json

# %%
response = url.urlopen("https://api.covid19india.org/states_daily.json")

# %%
data = json.load(response)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['states_daily'])

# %%
df = data['states_daily']

# %%
import pandas as pd

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#   an ap ar as br ch ct       date     dateymd dd  ... sk     status tg tn tr  \
# 0  0  1  0  0  0  0  0  14-Mar-20  2020-03-14  0  ...  0  Confirmed  1  1  0
# 1  0  0  0  0  0  0  0  14-Mar-20  2020-03-14  0  ...  0  Recovered  0  0  0
# 2  0  0  0  0  0  0  0  14-Mar-20  2020-03-14  0  ...  0   Deceased  0  0  0
# 3  0  0  0  0  0  0  0  15-Mar-20  2020-03-15  0  ...  0  Confirmed  2  0  0
# 4  0  0  0  0  0  0  0  15-Mar-20  2020-03-15  0  ...  0  Recovered  1  0  0
#
#    tt un  up ut wb
# 0  81  0  12  0  0
# 1   9  0   4  0  0
# 2   2  0   0  0  0
# 3  27  0   1  0  0
# 4   4  0   0  0  0
#
# [5 rows x 42 columns]

# %%
df.tail()
# Out:
#      an    ap   ar    as    br  ch    ct       date     dateymd dd  ...  sk  \
# 673  23  3572  168  2948  1084  78  2677  24-Oct-20  2020-10-18  0  ...  25
# 674   0    22    0     2     8   2    55  24-Oct-20  2020-10-18  0  ...   0
# 675  20  2997   33   204   749  61  1368  25-Oct-20  2020-10-18  0  ...  16
# 676  15  3585  170  2961  1399  80  1499  25-Oct-20  2020-10-18  0  ...  35
# 677   0    21    0     4     7   2    25  25-Oct-20  2020-10-18  0  ...   1
#
#         status    tg    tn   tr     tt un    up   ut    wb
# 673  Recovered  1708  4024  238  62270  0  2741  451  3753
# 674   Deceased     5    35    1    578  0    24    5    59
# 675  Confirmed   978  2869   86  45590  0  2032    0  4127
# 676  Recovered  1446  4019  146  58930  0  2368    0  3857
# 677   Deceased     4    31    3    473  0    28    0    60
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (678, 42)
